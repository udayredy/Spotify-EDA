# %% [markdown]
# # SPOTIFY EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data import

# %%
data=pd.read_csv('Popular_Spotify_Songs.csv',encoding='latin1')

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# ## Unique Values

# %%
def unique(x):
    print(x+":")
    print(data[x].unique())
    print()
for i in data.columns:
    unique(i)
# Out:
# track_name:
# ['Seven (feat. Latto) (Explicit Ver.)' 'LALA' 'vampire' 'Cruel Summer'
#  'WHERE SHE GOES' 'Sprinter' 'Ella Baila Sola' 'Columbia' 'fukumean'
#  'La Bebe - Remix' 'un x100to' 'Super Shy' 'Flowers' 'Daylight'
#  'As It Was' 'Kill Bill' 'Cupid - Twin Ver.'
#  'What Was I Made For? [From The Motion Picture "Barbie"]' 'Classy 101'
#  'Like Crazy' 'LADY GAGA'
#  'I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From The ' 'I Wanna Be Yours'
#  'Peso Pluma: Bzrp Music Sessions, Vol. 55'
#  'Popular (with Playboi Carti & Madonna) - The Idol Vol. 1 (Music from the HBO Original Series)'
#  'SABOR FRESA' 'Calm Down (with Selena Gomez)' 'MOJABI GHOST' 'Last Night'
#  'Dance The Night (From Barbie The Album)' 'Rush' 'TULUM' "Creepin'"
#  'Anti-Hero' 'TQG' 'Los del Espacio' 'Frï¿½ï¿½gil (feat. Grupo Front'
#  'Blank Space' 'Style' 'TQM' 'El Azul'
#  'Sunflower - Spider-Man: Into the Spider-Verse' "I'm Good (Blue)"
#  'See You Again' 'Barbie World (with Aqua) [From Barbie The Album]'
# ...

# %% [markdown]
# ## Null Values

# %%
data.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
data[data["streams"]=='BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3']
# Out:
#                               track_name     artist(s)_name  artist_count  \
# 574  Love Grows (Where My Rosemary Goes)  Edison Lighthouse             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 574           1970               1             1                  2877
#
#      in_spotify_charts                                            streams  \
# 574                  0  BPM110KeyAModeMajorDanceability53Valence75Ener...
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 574                  16  ...  110   A  Major             53         75
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 574       69              7                   0          17              3
#
# [1 rows x 24 columns]

# %%
data.drop(index=574,inplace=True)

# %%
data.streams=data.streams.astype('int64')

# %%
data[data["streams"]=='BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3']
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]

# %%
data['key']=data['key'].fillna(value=data['key'].mode().iloc[0])
data['in_shazam_charts']=data['in_shazam_charts'].fillna(value=data['key'].mode().iloc[0])

# %%
data.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
data.describe(include='all')
# Out:
#             track_name artist(s)_name  artist_count  released_year  \
# count              952            952    952.000000     952.000000
# unique             942            644           NaN            NaN
# top     Take My Breath   Taylor Swift           NaN            NaN
# freq                 2             34           NaN            NaN
# mean               NaN            NaN      1.556723    2018.288866
# std                NaN            NaN      0.893331      11.011397
# min                NaN            NaN      1.000000    1930.000000
# 25%                NaN            NaN      1.000000    2020.000000
# 50%                NaN            NaN      1.000000    2022.000000
# 75%                NaN            NaN      2.000000    2022.000000
# max                NaN            NaN      8.000000    2023.000000
#
#         released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# count       952.000000    952.000000            952.000000         952.000000
# ...

# %% [markdown]
# ## Numerical and Categorical features

# %%
numerical=pd.DataFrame(data.select_dtypes(include=['int64','float64']))
numerical
# Out:
#      artist_count  released_year  released_month  released_day  \
# 0               2           2023               7            14
# 1               1           2023               3            23
# 2               1           2023               6            30
# 3               1           2019               8            23
# 4               1           2023               5            18
# ..            ...            ...             ...           ...
# 948             1           2022              11             3
# 949             1           2022              10            21
# 950             2           2022              11             3
# 951             3           2022              10            20
# 952             1           2022              11             4
#
#      in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                     553                147  141381703                  43
# ...

# %%
categorical = pd.DataFrame(data.select_dtypes(include=['object']))
categorical
# Out:
#                               track_name      artist(s)_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 948                         My Mind & Me        Selena Gomez
# 949            Bigger Than The Whole Sky        Taylor Swift
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra
# 951                        En La De Ella  Feid, Sech, Jhayco
# 952                                Alone           Burna Boy
#
#     in_deezer_playlists in_shazam_charts key   mode
# 0                    45              826   B  Major
# 1                    58              382  C#  Major
# 2                    91              949   F  Major
# ...

# %% [markdown]
# ## Popular Songs visualization

# %%
data.streams = data.streams.astype('int64')

# %%
df=data.sort_values(by='streams', ascending=False)[:10]

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
sns.barplot(data=df, x='track_name', y='streams')
plt.title('Streams of Popular Spotify Songs')
plt.xlabel('Track Name')
plt.ylabel('Streams')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Highest Danceability musics

# %%
dance_df=data.sort_values(by='danceability_%',ascending=False)[:10]

# %%
dance_df
# Out:
#                       track_name                          artist(s)_name  \
# 595                         Peru                 Ed Sheeran, Fireboy DML
# 224                      Players                               Coi Leray
# 250          The Real Slim Shady                                  Eminem
# 423            Super Freaky Girl                             Nicki Minaj
# 702                    Starlight                                    Dave
# 321                        CAIRO               Karol G, Ovy On The Drums
# 876                     Ai Preto  L7nnon, DJ Biel do Furduncinho, Bianca
# 268                  Slut Me Out                              NLE Choppa
# 943           Privileged Rappers                        Drake, 21 Savage
# 142  Gol Bolinha, Gol Quadrado 2                     Mc Pedrinho, DJ 900
#
#      artist_count  released_year  released_month  released_day  \
# 595             2           2021              12            23
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=dance_df, x='track_name', y='danceability_%')
plt.title('Danceability of Songs')
plt.xlabel('Track Name')
plt.ylabel('Danceability')
plt.ylim(90,100)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Yearly Releases

# %%
release_y=data["released_year"]
r_y=pd.DataFrame(release_y.value_counts())
r_y=r_y.reset_index()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=r_y,x='released_year',y='count')
plt.title("No.of songs released yearly")
plt.xlabel("Years")
plt.ylabel("count")
plt.xticks(rotation=90,ha='right')
plt.show()

# %% [markdown]
# ## Artists Song counts

# %%
artists=pd.DataFrame(data['artist(s)_name'].value_counts())
artists.reset_index(inplace=True)
artistss=artists.sort_values(by='count',ascending=False)[:10]

# %%
sns.barplot(data=artistss,x="artist(s)_name",y="count")
plt.title("artist(s) Releases count")
plt.xlabel("Artist Name")
plt.ylabel("Total Release Count")
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## Oldest Songs

# %%
oldest=data.sort_values(by='released_year',ascending=True)[:10]
oldest[["track_name","released_year"]]
# Out:
#                                             track_name  released_year
# 439                                    Agudo Mï¿½ï¿½gi           1930
# 469                                    White Christmas           1942
# 460  The Christmas Song (Merry Christmas To You) - ...           1946
# 466             Let It Snow! Let It Snow! Let It Snow!           1950
# 459           A Holly Jolly Christmas - Single Version           1952
# 444                                   Jingle Bell Rock           1957
# 496                     Jingle Bells - Remastered 1999           1957
# 476  It's Beginning to Look a Lot Like Christmas (w...           1958
# 495                   Run Rudolph Run - Single Version           1958
# 443                  Rockin' Around The Christmas Tree           1958

# %%
data.in_deezer_playlists=data.in_deezer_playlists.str.replace(',', '').astype('int64')

# %% [markdown]
# ## Playlist Counts

# %%
data['Playlists_count']=data.in_spotify_playlists+data.in_apple_playlists+data.in_deezer_playlists
data["charts_count"]=data.in_spotify_charts+data.in_apple_charts+data.in_deezer_charts

# %%
play=data.sort_values(by=["Playlists_count"],ascending=False)
play[["track_name","artist(s)_name","in_spotify_playlists","in_apple_playlists","in_deezer_playlists","Playlists_count"]]
# Out:
#                                      track_name  \
# 624   Smells Like Teen Spirit - Remastered 2021
# 757                      Get Lucky - Radio Edit
# 720                     Wake Me Up - Radio Edit
# 630                              Mr. Brightside
# 199                                  Take On Me
# ..                                          ...
# 104                                   New Jeans
# 185                                     Cheques
# 112                                     LAGUNAS
# 94                               Still With You
# 327  Peaches (from The Super Mario Bros. Movie)
#
#                                  artist(s)_name  in_spotify_playlists  \
# 624                                     Nirvana                 49991
# 757  Pharrell Williams, Nile Rodgers, Daft Punk                 52898
# 720                                      Avicii                 50887
# 630                                 The Killers                 51979
# ...

# %% [markdown]
# ## Charts Count

# %%
chart=data.sort_values(by=["charts_count"],ascending=False)
chart[["track_name","artist(s)_name","in_spotify_charts","in_apple_charts","in_deezer_charts","charts_count"]]
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 12                                             Flowers
# 14                                           As It Was
# 17   What Was I Made For? [From The Motion Picture ...
# 2                                              vampire
# ..                                                 ...
# 821                                   The Heart Part 5
# 692                               Gospel (with Eminem)
# 815                                              SloMo
# 809  Mother I Sober (feat. Beth Gibbons of Portishead)
# 738                                             Chance
#
#                    artist(s)_name  in_spotify_charts  in_apple_charts  \
# 0                Latto, Jung Kook                147              263
# 12                    Miley Cyrus                115              215
# 14                   Harry Styles                130              198
# ...

# %% [markdown]
# ## Correlation

# %%
cor=numerical.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cor, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
threshold = 0.6  # Adjust as needed

# Extract features based on the threshold
selected_features = set()
for i in range(len(cor.columns)):
    for j in range(i):
        if abs(cor.iloc[i, j]) >= threshold:
            selected_features.add(cor.columns[i])
            selected_features.add(cor.columns[j])

# %%
selected_features=list(selected_features)
selected_features
# Out:
# ['streams',
#  'in_spotify_charts',
#  'in_spotify_playlists',
#  'in_apple_playlists',
#  'in_deezer_charts']
